# %% [markdown]
# #### 문제 1
# 사용자로부터 이름, 학번, 이번 학기 몇 학점을 수강하는지를 입력받은 후 입력된 정보를 출력하세요
#
# * 출력 예시
#
# ![ex_01.jpg](data:image/jpeg;base64,...)

# %%
### 문제 1

# %% [markdown]
# #### 문제 2
# 삼각형의 두 변의 길이 $a,b$ 와 그 사이의 끼인각 $\theta$의 크기가 주어졌을 때 삼각형의 넓이는 다음과 같습니다.
#
#
# $A = \frac{1}{2}\times a\times b \times sin\theta$
#
#
# $a,b,\theta$가 다음과 같이 주어졌을 때, 해당 수식을 구현하고 삼각형의 넓이를 구하세요.($math$ 모듈을 활용하세요)
#
# $a = 1, b = \sqrt{3}, \theta = \frac{\pi}{6}$
#
# * 출력
#
# ![ex_02.jpg](data:image/jpeg;base64,...)

# %%
### 문제 2

# %% [markdown]
# #### 문제 3
# 세 변의 길이가 $a,b,c$ 인 삼각형의 넒이 $A$를 구하는 공식은 다음과 같습니다.
#
# * $A = \sqrt{s(s-a)(s-b)(s-c))}$
# * $s=\frac{a+b+c}{2}$
#
# 해당 수식을 구현하고 세 변의 길이를 입력받아서 삼각형의 넓이를 구하세요.($math$ 모듈을 활용하세요)
#
# * 출력 예시
#
# ![ex_03.jpg](data:image/jpeg;base64,...)

# %%
### 문제 3
